# %% [markdown]
# ## Summary

# %% [markdown]
# The following script gathers data from the Youtube API. We will explore some basic metrics from a tech channel I'm currently subscribed to and do a bit of EDA on it's content. Unfortunately, dislikes have been disabled from public view so I will be focusing on content that is more popular. The idea is to give creators a quick overview of what topics are more popular with viewers.

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# ## Imports & Constants

# %% [markdown]
# ### Import Libs

# %%
from googleapiclient.discovery import build
import config
import numpy as np
import pandas as pd
import seaborn as sns
import requests
import missingno as msno
from matplotlib import rc_context
from matplotlib import ticker as tick
import matplotlib.pyplot as plt
import matplotlib.dates as md
# %matplotlib inline
import matplotlib.dates as mpl_dates
from scipy import stats
import datetime as dt
import time
from datetime import datetime
from datetime import date
sns.set(style="darkgrid")
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ### Constants

# %% [markdown]
# The API_KEY that I have is saved in a separate file that does not get pushed to my repo for security. If you want to run this script you'll need to create your own key via googles developer console enter it below. The CHANNEL_ID is from a popular tech channel I watch, there are tutorials out there that will explain how to get a unique content creators channel id. The youtube variable creates an API client to use with your requests.

# %%
API_KEY = config.API_KEY
CHANNEL_ID = 'UC0WNX0de8I1fgKUrjxiPaRA'
youtube = build('youtube', 'v3', developerKey= API_KEY)

# %% [markdown]
# ## Fetch Data

# %% [markdown]
# The fetch_channel_stats() method is used to gather some preliminary statistics on the channel. The request variable enables the user to query the API and returns a dictionary which is parsed. The playlist_id is what is necessary to access all the videos from the channel and has been returned as a string.

# %%
def fetch_channel_stats(youtube, CHANNEL_ID):
   
    request = youtube.channels().list(
                part="snippet,contentDetails,statistics",
                id=CHANNEL_ID)
    response = request.execute()
    print(response)
    for i in range(len(response['items'])):
        data = dict(Channel_name=response['items'][i]['snippet']['title'],
                    Subscriber = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics']['viewCount'],
                    Total_videos = response['items'][i]['statistics']['videoCount'],
                    playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
    #print(data)
    return data['playlist_id']

# %%
playlist_id = fetch_channel_stats(youtube, CHANNEL_ID)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'lSTuzsiGzzPwj2fmYdxPTVEXnSY', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'SRcW9h--mK5rD16QACgX7v2h350', 'id': 'UC0WNX0de8I1fgKUrjxiPaRA', 'snippet': {'title': 'Son of a Tech', 'description': 'Mailing Address\nNext Tuesday, LLC\n14546 Brook Hollow BLVD #356\nSan Antonio, TX 78232\n\nEmail\ninquiry@sonofatech.com\n\nAffiliate Links\nBT Miners https://bt-miners.com/?ref=dv617zq7oz\u200b\nWindows10: https://bit.ly/3mubZG2\u200b\nBlockFi: https://bit.ly/3eUMYjP\u200b\nAmazon: https://amzn.to/3bmHH2V\u200b\nHiveOS: https://bit.ly/2PX76cM\u200b\nTrezor: https://sonofatech.com/trezor\nCashApp: https://cash.app/app/MPLLCNW\u200b\nPrimeXBT: https://sonofatech.com/primexbt\nParallel Miner: https://bit.ly/2RwQclK\u200b\nCoinbase: https://bit.ly/33jNPW2\u200b\nMyTiki: https://mytiki.com/sonofatech\n', 'customUrl': 'sonofatech', 'publishedAt': '2012-10-25T08:00:51Z', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/tiZ77QTlwVuGLT6BEgB9fxeo40-lVUwFDFcAW6wn_e1wZ1jW9-OwpbQVut-qsN7SMt9uQ_rTqw=s88-c-k-c0x00ffffff-no-rj', 'width': 88, 'height': 88}, 'medium': {'url': 'https://yt3.ggpht.com/tiZ77QTlwVuGLT6BEgB9fxeo40-lVUwFDFcAW6wn_e1wZ1jW9-OwpbQVut-qsN7SMt9uQ_rTqw=s240-c-k-c0x00ffffff-no-rj', 'width': 240, 'height': 240}, 'high': {'url': 'https://yt3.ggpht.com/tiZ77QTlwVuGLT6BEgB9fxeo40-lVUwFDFcAW6wn_e1wZ1jW9-OwpbQVut-qsN7SMt9uQ_rTqw=s800-c-k-c0x00ffffff-no-rj', 'width': 800, 'height': 800}}, 'localized': {'title': 'Son of a Tech', 'description': 'Mailing Address\nNext Tuesday, LLC\n14546 Brook Hollow BLVD #356\nSan Antonio, TX 78232\n\nEmail\ninquiry@sonofatech.com\n\nAffiliate Links\nBT Miners https://bt-miners.com/?ref=dv617zq7oz\u200b\nWindows10: https://bit.ly/3mubZG2\u200b\nBlockFi: https://bit.ly/3eUMYjP\u200b\nAmazon: https://amzn.to/3bmHH2V\u200b\nHiveOS: https://bit.ly/2PX76cM\u200b\nTrezor: https://sonofatech.com/trezor\nCashApp: https://cash.app/app/MPLLCNW\u200b\nPrimeXBT: https://sonofatech.com/primexbt\nParallel Miner: https://bit.ly/2RwQclK\u200b\nCoinbase: https://bit.ly/33jNPW2\u200b\nMyTiki: https://mytiki.com/sonofatech\n'}, 'country': 'US'}, 'contentDetails': {'relatedPlaylists': {'likes': '', 'uploads': 'UU0WNX0de8I1fgKUrjxiPaRA'}}, 'statistics': {'viewCount': '25914120', 'subscriberCount': '177000', 'hiddenSubscriberCount': False, 'videoCount': '1565'}}]}

# %% [markdown]
# ## Video ID's

# %% [markdown]
# Retrieving the video ID's can be a bit tricky. The api only allows for the retrieval of 50 per request, but the entire list can be acquired using the nextPageToken. The initial query is written and excuted along with an empty list to store our unique id's in. If we have a look at the initial response as of today this channel has 1563 videos and the initial search gives 50 results. The nextPageToken key also holds a string value which we will need to save in order to construct the while loop so that we are able to run our query until all values have been saved to the video_id list. While more_pages is true the api query will execute and gather the id's 50 per query and append them until the next_page_token has no more information to retrieve.

# %%
def get_video_ids(youtube, playlist_id):
    request = youtube.playlistItems().list(
                part="contentDetails",
                playlistId=playlist_id,
                maxResults = 50)
    response = request.execute() 
    print(response)
    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
    
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part="contentDetails",
                        playlistId=playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute() 
    
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
    
            next_page_token = response.get('nextPageToken')
    
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)
# Out:
# {'kind': 'youtube#playlistItemListResponse', 'etag': 'wo4cCS-6TZWY_4eMwly-KrGOjmQ', 'nextPageToken': 'EAAaBlBUOkNESQ', 'items': [{'kind': 'youtube#playlistItem', 'etag': 'KWH4lSittcwrY7IpZ7jXf6PfqTs', 'id': 'VVUwV05YMGRlOEkxZmdLVXJqeGlQYVJBLkNoNTVRQUNGdmlZ', 'contentDetails': {'videoId': 'Ch55QACFviY', 'videoPublishedAt': '2022-05-01T22:49:25Z'}}, {'kind': 'youtube#playlistItem', 'etag': 'Z9Jh7sPHFKSHGeUxhdGsCa2Xai8', 'id': 'VVUwV05YMGRlOEkxZmdLVXJqeGlQYVJBLjB3LUp1a0VfTmRZ', 'contentDetails': {'videoId': '0w-JukE_NdY', 'videoPublishedAt': '2022-05-01T19:00:00Z'}}, {'kind': 'youtube#playlistItem', 'etag': '2V_VSSdUtCgfGP-f7FqaXQm_qic', 'id': 'VVUwV05YMGRlOEkxZmdLVXJqeGlQYVJB
'L04WPT6Dfmg', '-AmAK3nofYI', 'umqDoOvez2I', '7iXqMocl3GE', 'UyiMsOar5uw', 'mF4Z0y-0xL4', 'TBmlqF_7-_Y', 'eq58ugpM5dI', 'WWgorcsFU9U', 'jx1svpG5GMk', 'r8wvNqNxSXI', '5P0D8WHYxkw', 'C8GqcUKdKa0', 'wFYc2Vn4TEs', 'TkON99geFQg', 'NODWaeyguZk', 'T6xan05VfHw', 'FweV-v_gJIA', 'cpH5eH0_nm4', '8Kh-wH6sM4c', 'h8SqBSYRs_k', '7eopeJfin84', '2a7_Yt72rx0', 'P4KMSf_JL74', 'OZ7zzQJvDC0', 'MPw2tQl_noI', 'JA0qwbUzP-U', 'GdW_wqcMUUk', 'rxZYEs3Jp1Q', 'zcJd251Xv9o', 'SqikOuqUmWQ', 'h5ELf9yT870', 'vRqzBPh0e1I', '_paPmpvmHIk', 'nYu0RlUB-pY', 'ejVYVLN4w20', 'QWLozNuZdZA', 'uoqMytJ_NTs', 'Yv5BmdQ-WCs', 'k2fLorNccdI', '6JBzApGcn5c', 'ig8vJ8hGM94', 'uwVVvoj-I5I', 'vCUjsr73qdo', 'kub-coLLEOQ', 'UBhCG_eVidA', 'P62ZA0eJ3AE', 'ETfqudx-9IM', 'mXzKvCFQC0A', 'ThlhbTGd840', 'FfQkaWcs ...

# %%
request = youtube.commentThreads().list(
            part="snippet,replies",
            videoId= '5Gf2TXmNweg',
            maxResults = 50)
response = request.execute()

# %%
print(response)
# Out:
# {'kind': 'youtube#commentThreadListResponse', 'etag': 'zAa_XqiKlze9V-XfS6U3jtoqdZc', 'pageInfo': {'totalResults': 40, 'resultsPerPage': 50}, 'items': [{'kind': 'youtube#commentThread', 'etag': 'AmDZYz3QPqCq1L8BSnBgc72Xcwg', 'id': 'UgwPBZOU35IYjQ877Id4AaABAg', 'snippet': {'videoId': '5Gf2TXmNweg', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'rIUWK7IlA2wTRrHn78gSQfjZvVw', 'id': 'UgwPBZOU35IYjQ877Id4AaABAg', 'snippet': {'videoId': '5Gf2TXmNweg', 'textDisplay': 'Great&lt; video and some nice tips! This is a scary time for new investors but the best thing you can do is not to make decisions based on emotions. This could actually be a good time to buy more of your high conviction stocks or crypto on a discount. Wealth is created during bear markets, not bull markets. If your portfolio is really effecting your mental health then delete the app and go for a walk. Let the market do its thing and have a long time horizon. I buy and just trade long term more than ever, I have made over 16` btc from day trading with Jennifer Wilbur Crypto in few weeks this is one of the best medium to backup your assets incase it goes bearish <a href="about:invalid#zCSafez"></a>', 'textOriginal': 'Great< video and some nice tips! This is a scary time for new investors but the best thing you can do is not to make decisions based on emotions. This could actually be a good time to buy more of your high conviction stocks or crypto on a discount. Wealth is created during bear markets, not bull markets. If your portfolio is really effecting your mental health then delete the app and go for a walk. Let the market do its thing and have a long time horizon. I buy and just trade long term more than ever, I have made over 16` btc from day trading with Jennifer Wilbur Crypto in few weeks this is one of the best medium to backup your assets incase it goes bearish ', 'authorDisplayName': 'Marteen Summers', 'authorProfileImageUrl': 'https://yt3.ggpht.com/NOvOJ9Hkv3Q4MzT4EljhkniT53sUJKVfS5VRoVfjGjVJI6JMF25astOyA7cpT9pAhFIwvUw1=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCcagNhsx2QUjg4meQ9DKHjw', 'authorChannelId': {'value': 'UCcagNhsx2QUjg4meQ9DKHjw'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 52, 'publishedAt': '2022-04-18T19:27:48Z', 'updatedAt': '2022-04-18T19:27:48Z'}}, 'canReply': True, 'totalReplyCount': 9, 'isPublic': True}, 'replies': {'comments': [{'kind': 'youtube#comment', 'etag': 'heOjeVGh6UI6_j02tbZTOyNDPcY', 'id': 'UgwPBZOU35IYjQ877Id4AaABAg.9_yll2gql8g9_ypO9Tsp2n', 'snippet': {'videoId': '5Gf2TXmNweg', 'textDisplay': 'I will forever be indebted to Jennifer Wilbur, I was able to build a massive income stream during the covid-19 pandemic trading with her. she revolutionized my trading experience.', 'textOriginal': 'I will forever be indebted to Jennifer Wilbur, I was able to build a massive income stream during the covid-19 pandemic trading with her. she revolutionized my trading experience.', 'parentId': 'UgwPBZOU35IYjQ877Id4AaABAg', 'authorDisplayName': 'Suzanne Mckechnie', 'authorProfileImageUrl': 'https://yt3.ggpht.com/IL_B5HSlOmAVEtpMZdvz03vgHLJ40OvacPUcp1BcME3xi6X7dhvktGcaGMvUcfnRM2eClg9BtTw=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UC8c4RO6o5r5c92nPLePmoOA', 'authorChannelId': {'value': 'UC8c4RO6o5r5c92nPLePmoOA'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2022-04-18T19:59:30Z', 'updatedAt': '2022-04-18T19:59:30Z'}}, {'kind': 'youtube#comment', 'etag': 'CXk5Kv5kagf1Ax2vNJC9npRHLoI', 'id': 'UgwPBZOU35IYjQ877Id4AaABAg.9_yll2gql8g9_ypJMSKuGI', 'snippet': {'videoId': '5Gf2TXmNweg', 'textDisplay': 'This is very impressive , meeting Jennifer Wilbur has been a blessing , I never thought I would make so much profits in a short period of time.', 'textOriginal': 'This is very impressive , meeting Jennifer Wilbur has been a blessing , I never thought I would make so much profits in a short period of time.', 'parentId': 'UgwPBZOU35IYjQ8 ...

# %%
for i in range(len(video_ids)):
    request = youtube.commentThreads().list(
            part="snippet,replies",
            videoId= video_ids[i],
            maxResults = 50)
    response = request.execute()
    
    reply_db = []
    toplev_db = []
    
    for i in range(len(response['items'])):
        if response['items'][i]["snippet"]["totalReplyCount"] > 0:
            reply_id = response['items'][i]["replies"]["comments"][0]['snippet']['videoId']
            reply_text = response['items'][i]["replies"]["comments"][0]['snippet']['textOriginal']
            reply_db.append([reply_id, reply_text])

        top_id = response['items'][i]["snippet"]['topLevelComment']['snippet']['videoId']
        top_text = response['items'][i]["snippet"]['topLevelComment']['snippet']['textOriginal']
        toplev_db.append([top_id, top_text])
    
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.commentThreads().list(
                    part="snippet,replies",
                    videoId= video_ids[i],
                    maxResults = 50,
                    pageToken = next_page_token)
            response = request.execute()
            print(response)
           
    
            next_page_token = response.get('nextPageToken')
# Out:
# {'kind': 'youtube#commentThreadListResponse', 'etag': 'zAa_XqiKlze9V-XfS6U3jtoqdZc', 'pageInfo': {'totalResults': 40, 'resultsPerPage': 50}, 'items': [{'kind': 'youtube#commentThread', 'etag': 'AmDZYz3QPqCq1L8BSnBgc72Xcwg', 'id': 'UgwPBZOU35IYjQ877Id4AaABAg', 'snippet': {'videoId': '5Gf2TXmNweg', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'rIUWK7IlA2wTRrHn78gSQfjZvVw', 'id': 'UgwPBZOU35IYjQ877Id4AaABAg', 'snippet': {'videoId': '5Gf2TXmNweg', 'textDisplay': 
...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21948/2915262352.py in <module>
#      10     for i in range(len(response['items'])):
#      11         if response['items'][i]["snippet"]["totalReplyCount"] > 0:
# ---> 12             reply_id = response['items'][i]["replies"]["comments"][0]['snippet']['videoId']
#      13             reply_text = response['items'][i]["replies"]["comments"][0]['snippet']['textOriginal']
#      14             reply_db.append([reply_id, reply_text])
#
# KeyError: 'replies'

# %%
 for i in range(len(response['items'])):
                if response['items'][i]["snippet"]["totalReplyCount"] > 0:
                    reply_id = response['items'][i]["replies"]["comments"][0]['snippet']['videoId']
                    reply_text = response['items'][i]["replies"]["comments"][0]['snippet']['textOriginal']
                    reply_db.append([reply_id, reply_text])

                top_id = response['items'][i]["snippet"]['topLevelComment']['snippet']['videoId']
                top_text = response['items'][i]["snippet"]['topLevelComment']['snippet']['textOriginal']
                toplev_db.append([top_id, top_text])

# %%
print( response)
# Out:
# {'kind': 'youtube#commentThreadListResponse', 'etag': 'raCkM683bmUBYaiV_SjjMql2jsk', 'nextPageToken': 'QURTSl9pM2FxbkFQLUtzTU1GNDA2MkJYVXhWUnZHOTY2Q1A4Mi0ycFpyNzJ5TFdrQTZSb1cxSFppZkZYNFc1aXAybXBVY0twTFI5SWFsYw==', 'pageInfo': {'totalResults': 20, 'resultsPerPage': 20}, 'items': [{'kind': 'youtube#commentThread', 'etag': 'UjxbSyozYk1uVySKH2azS04TtIM', 'id': 'UgxQ7DTEUSXmzA8-f9h4AaABAg', 'snippet': {'videoId': 'OK_ltSEzRmM', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'b0e9U7TreMoAtz_V0Z9AzJoYUNs', 'id': 'UgxQ7DTEUSXmzA8-f9h4AaABAg', 'snippet': {'videoId': 'OK_ltSEzRmM', 'textDisplay': 'Can you make a tutorial on how to mine with them?', 'textOriginal': 'Can you make a tutorial on how to mine with them?', 'authorDisplayName': 'Elendilion', 'authorProfileImageUrl': 'https://yt3.ggpht.com/Qi8LwB_9Kgoxr88Om-p2ptK4aeqalNcIBf1zAvhmCT0ugEn-ZUjgQ8GoR6zUrxCIZuqtfCCTl0c=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCZqP3B7NUHkPtz747_vaRuA', 'authorChannelId': {'value': 'UCZqP3B7NUHkPtz747_vaRuA'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2021-04-25T01:02:07Z', 'updatedAt': '2021-04-25T01:02:07Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}, {'kind': 'youtube#commentThread', 'etag': '-sH0qHJ9MGh0QRC-2o785t_1SMM', 'id': 'UgwQQwUycL-4sBaFBGJ4AaABAg', 'snippet': {'videoId': 'OK_ltSEzRmM', 'topLevelComment': {'kind': 'youtube#comment', 'etag': '2J9YuYOEN4OabbHiBYBqPn5UQec', 'id': 'UgwQQwUycL-4sBaFBGJ4AaABAg', 'snippet': {'videoId': 'OK_ltSEzRmM', 'textDisplay': 'Yo', 'textOriginal': 'Yo', 'authorDisplayName': 'sashking', 'authorProfileImageUrl': 'https://yt3.ggpht.com/eYGb2wkz1h352zCB02IFH17lmbWWrL97_eqKgDTkM9LV48nMjsX7zgR0Qm1mjR5hqcFnnaYhck0=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCuy4Q-mmXH6LodRExXvVGLw', 'authorChannelId': {'value': 'UCuy4Q-mmXH6LodRExXvVGLw'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2021-03-24T16:37:54Z', 'updatedAt': '2021-03-24T16:37:54Z'}}, 'canReply': True, 'totalReplyCount': 2, 'isPublic': True}, 'replies': {'comments': [{'kind': 'youtube#comment', 'etag': 'Pw6CtINCuye4hxm3LfCDVc3VOIM', 'id': 'UgwQQwUycL-4sBaFBGJ4AaABAg.9LHFIM1ioi79LHQnM6T1tJ', 'snippet': {'videoId': 'OK_ltSEzRmM', 'textDisplay': '@Son of a Tech xP I wouldn&#39;t call it bad. <br>I have one question, is there a way to get into rocket-chat with crypto? YouTube doesn&#39;t let me pay with any cryptocurrency for channel membership...', 'textOriginal': "@Son of a Tech xP I wouldn't call it bad. \nI have one question, is there a way to get into rocket-chat with crypto? YouTube doesn't let me pay with any cryptocurrency for channel membership...", 'parentId': 'UgwQQwUycL-4sBaFBGJ4AaABAg', 'authorDisplayName': 'sashking', 'authorProfileImageUrl': 'https://yt3.ggpht.com/eYGb2wkz1h352zCB02IFH17lmbWWrL97_eqKgDTkM9LV48nMjsX7zgR0Qm1mjR5hqcFnnaYhck0=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCuy4Q-mmXH6LodRExXvVGLw', 'authorChannelId': {'value': 'UCuy4Q-mmXH6LodRExXvVGLw'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2021-03-24T18:18:23Z', 'updatedAt': '2021-03-24T18:18:23Z'}}, {'kind': 'youtube#comment', 'etag': 'qxJzDJYOf_esBBBUf0PRSHmxnIM', 'id': 'UgwQQwUycL-4sBaFBGJ4AaABAg.9LHFIM1ioi79LHFVT7M3tn', 'snippet': {'videoId': 'OK_ltSEzRmM', 'textDisplay': 'you going back to see how bad my old videos were? lol', 'textOriginal': 'you going back to see how bad my old videos were? lol', 'parentId': 'UgwQQwUycL-4sBaFBGJ4AaABAg', 'authorDisplayName': 'Son of a Tech', 'authorProfileImageUrl': 'https://yt3.ggpht.com/tiZ77QTlwVuGLT6BEgB9fxeo40-lVUwFDFcAW6wn_e1wZ1jW9-OwpbQVut-qsN7SMt9uQ_rTqw=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UC0WNX0de8I1fgKUrjxiPaRA', 'authorChannelId': {'value': 'UC0WNX0de8I1fgKUrjxiPaRA'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2021-03-24T16:39:4 ...

# %%
    reply_db = []
    toplev_db = []
    for i in range(len(response['items'])):
    if response['items'][i]["snippet"]["totalReplyCount"] > 0:
        reply_id = response['items'][i]["replies"]["comments"][0]['snippet']['videoId']
        reply_text = response['items'][i]["replies"]["comments"][0]['snippet']['textOriginal']
        reply_db.append([reply_id, reply_text])
        
    top_id = response['items'][i]["snippet"]['topLevelComment']['snippet']['videoId']
    top_text = response['items'][i]["snippet"]['topLevelComment']['snippet']['textOriginal']
    toplev_db.append([top_id, top_text])

# %%
print(response['items'][0]["snippet"]["totalReplyCount"])
# Out:
# 0

# %%
reply_db = []
toplev_db = []
for i in range(len(response['items'])):
    if response['items'][i]["snippet"]["totalReplyCount"] > 0:
        reply_id = response['items'][i]["replies"]["comments"][0]['snippet']['videoId']
        reply_text = response['items'][i]["replies"]["comments"][0]['snippet']['textOriginal']
        reply_db.append([reply_id, reply_text])
        
    top_id = response['items'][i]["snippet"]['topLevelComment']['snippet']['videoId']
    top_text = response['items'][i]["snippet"]['topLevelComment']['snippet']['textOriginal']
    toplev_db.append([top_id, top_text])

# %%
print(reply_db)
# Out:
# [['OK_ltSEzRmM', "@Son of a Tech xP I wouldn't call it bad. \nI have one question, is there a way to get into rocket-chat with crypto? YouTube doesn't let me pay with any cryptocurrency for channel membership..."], ['OK_ltSEzRmM', "+Blindrun Aah, makes sense. Thanks for clarifying. I'm on PC unfortunately (fortunately? :))"], ['OK_ltSEzRmM', 'yes'], ['OK_ltSEzRmM', "Didn't work"], ['OK_ltSEzRmM', '+Blindrun thanks you so much this link has helped me the best had a lot of problems saw a lot of videos but it depends what you have one video may help some but some not because of the different ways to connect your headset and trough this link you can choose the way you have it connected and the setting you need < (my problem i had ) hope this helps the guys who are reading this who also are having problems, just go to the link and look for your headset'], ['OK_ltSEzRmM', '@***** oh no idea about ps3 sorry. On pc its simply in the audio settings...'], ['OK_ltSEzRmM', 'Nop, you only have one USB that can go into the PC OR the PS3']]

# %%
print(toplev_db)

# %% [markdown]
# ## Function to get video stats

# %% [markdown]
# The stats we will be retrieving are title, published date, view counts, likes, and comments.
# Using the video_ids we will gather the statistics into a dictionary and append them to our list in increments of 50 per request.

# %%
def get_video_details(youtube, video_ids):

    all_video_stats = []
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
                    part="snippet,contentDetails,statistics",
                    id=','.join(video_ids[i:i+50]))
        response = request.execute()
        
        for video in response['items']:
            video_stats = dict(Title= video['snippet']['title'],
                              Published_date= video['snippet']['publishedAt'].split("T")[0],
                              Views= video['statistics']['viewCount'],
                              Likes= video['statistics']['likeCount'],
                              Comments= video['statistics']['commentCount'])
    
            all_video_stats.append(video_stats)
    return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)

# %%
# lst.append(lst.pop(lst.index('string2')))

# %% [markdown]
# ## DataFrame

# %% [markdown]
# Now that we have our data in a manageable format it is possibe to tranform the list of dictionarys extracted via the API into a pandas DataFrame where we can do some data analysis. The code below simply imports video_details into the desired formats and recasts the data into types we can work with.

# %%
video_data = pd.DataFrame(video_details)
video_data['Published_date'] = pd.to_datetime(video_data['Published_date'], format='%Y-%m-%d')
video_data = video_data.astype({'Views':'int64','Likes':'int64','Comments':'int64'})

# %%
def get_summary_stats(df):
    
    """
    Function get_summary_stats prints DF statistics to the console.
    
    Output is given in standard form to the console. If the set_option('display.expand_frame_repr', False)
    method is set to True the output will not wrap vertically in the console window.
        
    Args:
        df (Pandas DataFrame): Dataframe created from AWS query
    """
    
    pd.set_option('display.expand_frame_repr', False)
    print(df.info(),'\n')
    print(df.describe(),'\n')
    print(df.head())
    msno.matrix(df)
    plt.show()

# %%
get_summary_stats(video_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1563 entries, 0 to 1562
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           1563 non-null   object
#  1   Published_date  1563 non-null   datetime64[ns]
#  2   Views           1563 non-null   int64
#  3   Likes           1563 non-null   int64
#  4   Comments        1563 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 61.2+ KB
# None
#
#               Views         Likes     Comments
# count  1.563000e+03   1563.000000  1563.000000
# mean   1.658877e+04    435.966731    97.339091
# std    4.999865e+04   1174.736783   244.712824
# min    1.800000e+01      0.000000     0.000000
# 25%    1.865000e+03     54.000000    12.000000
# 50%    5.148000e+03    165.000000    38.000000
# 75%    1.574350e+04    449.500000   108.000000
# max    1.526738e+06  38026.000000  7524.000000
#
#                                                Title Published_date  Views  Likes  Comments
# 0                             RTX 4090 TI 900 Watts!     2022-05-01   3889    146       118
# 1                 Bitcoin Hashrate Continues to Rise     2022-04-30   1775    104        38
# 2  Crypto Industry Reacts to Musk's Twitter Purchase     2022-04-30   1681    102        34
# 3                       Bitcoin Miners Leverage Debt     2022-04-30   3253    119        42
# 4                             The History of Bitcoin     2022-04-29   2145    143        37

# %%
def top10_last10(df):
    
    """
    Function top10_last10 plots the most and least viewed videos.
    
    The top barchart is depicted in millions of views note the 1e6 scientific notation.
        
    Args:
        df (Pandas DataFrame): Dataframe created from Youtube API query
    """
    
    top10_views = df.sort_values(by='Views', ascending=False).head(10)
    least10_views = df.sort_values(by='Views', ascending=False).tail(10)
    fig, axs = plt.subplots(figsize=(11,7),nrows=2)
    sns.set_palette("bright")
    sns.barplot(x="Views", y="Title", data=top10_videos, ax=axs[0]).set(title='Views (M)')
    axs[0].set(xlabel=None)
    axs[0].set(ylabel=None)
    sns.barplot(x="Views", y="Title", data=least10_views, ax=axs[1])
    axs[1].set(ylabel=None)

# %%
top10_last10(video_data)

# %%
mine_count = video_data['Title'].str.contains('mining', case= False).sum()
if mine_count > 0:
    print (f"There are {mine_count} Mels")
# Out:
# There are 258 Mels

# %%
ax1 = sns.barplot(x='Views', y='Title', data=top10_videos)
ax2 = sns.barplot(x='Views', y='Title', data=least10_views)

# %%
video_data['Month'] = pd.to_datetime(video_data['Published_date']).dt.strftime('%b')

# %%
videos_per_month = video_data.groupby('Month', as_index=False).size()

# %%
videos_per_month
# Out:
#    Month  size
# 0    Apr   172
# 1    Aug   107
# 2    Dec   119
# 3    Feb   191
# 4    Jan   186
# 5    Jul   104
# 6    Jun    80
# 7    Mar   230
# 8    May    74
# 9    Nov    99
# 10   Oct    85
# 11   Sep    93

# %%
sort_order = ['Jan','Feb','Mar','Apr','May','Jun',
             'Jul','Aug','Sep','Oct','Nov','Dec']

# %%
videos_per_month.index = pd.CategoricalIndex(videos_per_month['Month'], categories=sort_order,ordered=True)

# %%
videos_per_month = videos_per_month.sort_index()

# %%
ax2 = sns.barplot(x='Month', y='size', data=videos_per_month)

# %%
df_temp['Date'] = pd.to_datetime(df_temp['Date'], unit='s').dt.normalize()
df = df_temp.astype({'Views':'int64','Likes':'int64','Comments':'int64'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3820/2419105436.py in <module>
# ----> 1 df_temp['Date'] = pd.to_datetime(df_temp['Date'], unit='s').dt.normalize()
#       2 df = df_temp.astype({'Views':'int64','Likes':'int64','Comments':'int64'})
#
# NameError: name 'df_temp' is not defined

# %%
df = pd.DataFrame(columns=['video_id','video_title','upload_date','view_count','like_count','comment_count'])

# %%
    def get_stats(video_id): 
    
        url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
        response_video_stats = requests.get(url_video_stats).json()
        view_count = response_video_stats['items'][0]['statistics']['viewCount']
        like_count = response_video_stats['items'][0]['statistics']['likeCount']
        comment_count = response_video_stats['items'][0]['statistics']['commentCount']
        
        return view_count, like_count, comment_count

# %%
def get_vids(df):
    #make an api call
    pageToken = ""
    nextPageToken = ""
    #CDIQAA
    url = "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet&id&order=date&maxResults=10000&"+pageToken
    response = requests.get(url).json()
    print(response)
    time.sleep(1)
    
    for video in response['items']:
        if video['id']['kind'] == 'youtube#video':
            video_id = video['id']['videoId']
            video_title = video['snippet']['title']
            #video_title = str(video_title).replace("&amp;","") format string as necessary
            upload_date = video['snippet']['publishedAt']
            upload_date = str(upload_date).split("T")[0]

            view_count, like_count, comment_count = get_stats(video_id)

            df = df.append({'video_id':video_id,'video_title':video_title,'upload_date':upload_date,
                            'view_count':view_count,'like_count':like_count,'comment_count':comment_count}
                             , ignore_index = True)
    return(df)

# %%
1586

# %%
df = get_vids(df)

# %%
df.info()

# %%
df['upload_date'] = pd.to_datetime(df['upload_date'])

# %%
df.info()

# %%
df.sort_values(by='upload_date')
df.drop_duplicates(subset ="video_title", keep = False, inplace = True)

# %%
df.info()

# %%
def connect_to_db(host_name, dbname, port, username, password):
    try:
        conn = ps.connect(host= host_name, dbname= dbname, user=username, password= password, port=port)

    except ps.OperationalError as e:
        raise e

    else:
        print('Connected!')
        
        return conn

# %%
#create the table
def create_table(curr):
    create_table_command = ("""CREATE TABLE IF NOT EXISTS videos (
                            video_id VARCHAR(255) PRIMARY KEY,
                            video_title TEXT NOT NULL,
                            upload_date DATE NOT NULL DEFAULT CURRENT_DATE,
                            view_count INTEGER NOT NULL,
                            like_count INTEGER NOT NULL,
                            comment_count INTEGER NOT NULL
                            )""")
    curr.execute(create_table_command)

# %%
def check_if_video_exists(curr, video_id):
    query= ("""SELECT video_id FROM VIDEOS WHERE video_id = %s""")
    curr.execute(query, (video_id,))
    
    return curr.fetchone() is not None

# %%
def update_row(curr, video_id, video_title, upload_date, view_count, like_count, comment_count):
    query = ("""UPDATE videos
            SET video_title = %s,
                view_count = %s,
                like_count = %s,
                comment_count = %s
            WHERE video_id = %s;""")
    vars_to_update = (video_id, video_title, upload_date, view_count, like_count, comment_count)
    curr.execute(query, vars_to_update)

# %%
def update_db(curr,df):
    tmp_df = pd.DataFrame(columns=['video_id','video_title','upload_date','view_count','like_count','comment_count'])

    for i, row in df.iterrows():
        if check_if_video_exists(curr, video_id):
            update_row(curr, row['video_id'], row['video_title'], row['upload_date'], row['view_count'], row['like_count'], row['comment_count'])
        else:
            tmp_df = tmp_df.append(row)
            
    return tmp_df

# %%
def insert_into_table(curr, video_id, video_title, upload_date, view_count, like_count, comment_count):
    insert_into_videos = ("""INSERT INTO videos (video_id, video_title, upload_date, view_count, like_count, comment_count)
                         VALUES(%s, %s,%s,%s,%s,%s);""")
    row_to_insert = (video_id, video_title, upload_date, view_count, like_count, comment_count)
    curr.execute(insert_into_videos, row_to_insert)

# %%
def append_from_df_to_db(curr,df):
    for i, row in df.iterrows():
        insert_into_table(curr, row['video_id'], row['video_title'], row['upload_date'], row['view_count'], row['like_count'], row['comment_count'])

# %%
#conn = None

# %%
conn = connect_to_db(config.DB_HOST, config.DB_NAME, config.DB_PORT, config.DB_USER, config.DB_PASS)

# %%
curr = conn.cursor()

# %%
create_table(curr)

# %%
new_vid_df = update_db(curr,df)

# %%
append_from_df_to_db(curr,new_vid_df)

# %%
conn.commit()

# %%
df.head()
